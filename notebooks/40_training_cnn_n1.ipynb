# %% [markdown]
# **For correct rendering, view this notebook in [nbviewer](https://nbviewer.org/github/markuskrecik/preference-dynamics-learning/blob/main/notebooks/40_training_cnn_n1.ipynb)**
#
# # 1d CNN Model Training for n=1 action
#
# This notebook trains a 1d CNN model to predict preference dynamics parameters in the case of n=1 action.
#
# The CNN pytorch model is automatically constructed through the `CNN1DPredictor` class with a `CNN1DConfig`. It combines multiple initial convolutional and pooling layers with subsequent fully connected layers.
#
# The Trainer class is configured through the `TrainerConfig`. The training loop stops early if a validation DataLoader is provided. The trainer automatically creates checkpoints of the training and model state for the best and last epoch, and supports resuming from a checkpoint. If the trainer is running in a mlflow run, training metrics are automatically logged.
#
# The `ExperimentRunner` class can perform single runs and parallelized hyperparameter optimization studies through Optuna with mlflow logging. It supports resuming previous studies. Parameter studies are defined through subclassing with a `suggest_parameters` method.
# mlflow runs can be examined in the UI through `uv run mlflow ui --port 5000 --backend-store-uri sqlite:///mlruns.db`.
#
# All classes can be extensively configured through their config schemas beyond the options shown here.
#
# **This notebook:**
# - Trains a 1d CNN model for the easiest case of n=1 action
# - Evaluates the model on the test set with various metrics
# - Performs a hyperparameter study to identify the best configuration of convolutional and hidden layers
# - Compares time series of true and predicted parameters
#
#
# ## Training for 1 action

# %%
# %load_ext autoreload
# %autoreload 2


import numpy as np
from optuna.visualization import plot_parallel_coordinate, plot_contour
from plotly.offline import init_notebook_mode

init_notebook_mode(connected=True)

from preference_dynamics.schemas import (
    ParameterVector,
    ICVector,
    ODEConfig,
    SolverConfig,
    ODESolverConfig,
    TrainerConfig,
    RunnerConfig,
)

from preference_dynamics.solver import create_default_sampler, generate_batch, solve_ODE
from preference_dynamics.data import DataConfig, DataManager
from preference_dynamics.data.transformer import SampleGroupStdNormalizer
from preference_dynamics.data.adapters import StateInputAdapter, ParameterICTargetAdapter
from preference_dynamics.models import CNN1DConfig
from preference_dynamics.training import compute_metrics
from preference_dynamics.experiments import ExperimentRunner
from preference_dynamics.visualization import (
    plot_metrics,
    plot_parameter_comparison,
    plot_time_series,
    plot_training_curves,
)
from preference_dynamics.utils import (
    num_params,
    num_vars,
    assemble_checkpoint_path,
    get_param_names,
    get_var_names,
)


n_actions = 1
data_dir = f"data/n{n_actions}"
model_name = f"cnn1d_n{n_actions}"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>

# %% [markdown]
# ### Preliminaries
#
# Generate data if not done already, otherwise load it. I circumvent the previously identified identifiability issue of $\mu$ by setting it to 0 while sampling.
#
# The transformer `SampleGroupStdNormalizer` normalizes each variable group (desires, efforts) separately for each sample through the standard deviation. I don't shift the mean to 0, because this would erase the information about the steady state.
#
# The input and output adapters serve as a flexible way to define model input data and model predictions without having to change the model architecture. Here, I specify that the model receives the state vector as input through `StateInputAdapter` and predicts parameters and initial conditions through `ParameterICTargetAdapter`.

# %%
data_config = DataConfig(
    data_dir=data_dir,
    load_if_exists=False,
    transformers=[
        SampleGroupStdNormalizer(),
    ],
    input_adapter=StateInputAdapter(),
    target_adapter=ParameterICTargetAdapter(),
)
dm = DataManager(config=data_config)

try:
    dm.setup()
except FileNotFoundError:
    n_samples = 10000
    seed = 42

    sampler = create_default_sampler(
        n_actions=n_actions,
        random_seed=seed,
        mu_range=(0.0, 0.0),
    )

    solver_config = SolverConfig(
        time_span=(0.0, 200.0),
        n_time_points=201,
    )

    print(f"Generating {n_samples} samples for n={n_actions} actions...")
    batch = generate_batch(
        n_samples,
        sampler,
        solver_config,
        n_jobs=-1,
        show_progress=True,
        debug=False,
    )
    dm.save_raw(batch)

    dm.setup()

# %% [markdown]
# ### Model Training
#
# Let's start with a tiny model:
# - 1 convolutional layer with kernel size 3
# - 1 global pooling layer
# - A dropout layer
# - 1 hidden layer with 32 neurons
# - All activation functions are ReLU

# %%
model_config = CNN1DConfig(
    model_name=model_name,
    in_channels=dm.n_inputs,
    filters=[64],
    kernel_sizes=[3],
    features=[32, dm.n_targets],
    dropout=0.3,
)

trainer_config = TrainerConfig(
    loss_function="mse",
    learning_rate=0.002,
    num_epochs=200,
    early_stopping_patience=20,
)

runner_config = RunnerConfig(
    experiment_name=f"preference_dynamics_n{n_actions}",
)

runner = ExperimentRunner(
    runner_config=runner_config,
    data_config=data_config,
    model_config=model_config,
    trainer_config=trainer_config,
)

# %%
experiment = runner.run("base")

plot_training_curves(experiment.history)
# Out:
# Training:  70%|███████   | 140/200 [05:55<02:32,  2.54s/it, epoch=140, train_loss=1.01, val_loss=0.992, epoch_time=1.32]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="04a0b21c-8fa3-4e70-900d-d66704929b8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("04a0b21c-8fa3-4e70-900d-d66704929b8b")) {                    Plotly.newPlot(                        "04a0b21c-8fa3-4e70-900d-d66704929b8b",                        [{"marker":{"size":6},"mode":"lines+markers","name":"Train Loss","x":{"dtype":"i2","bdata":""},"y":[3.8863779825901767,2.2169902778546744,2.0125375318964687,1.8739785163774403,1.8067460787405663,1.8398610003497622,1.7712405466158456,1.630661164401868,1.5704529829528353,1.507456169215911,1.4236290963417892,1.3860704603545162,1.3221670263404146,1.2899859233186879,1.256127953529358,1.2575228364642608,1.2071345221558842,1.1974622287334653,1.1774366804219167,1.1731820604123107,1.1550914735422222,1.1662682499907433,1.1542552236570132,1.1473982334136963,1.1382073565907436,1.1366471626342984,1.1490584696651598,1.1333259489011327,1.1161825082717685,1.1175661128048504,1.1240327935153192,1.1049332777294545,1.1022558234153537,1.095950024937271,1.0927693625108912,1.0867494615392947,1.0832217784102904,1.0807073201061388,1.0960760958697817,1.0704840019755406,1.0910070795531666,1.0725213029515852,1.0708900963494536,1.0688828451370975,1.0681622821256656,1.0713470192677383,1.062892208405591,1.061371712646353,1.0594318156395484,1.0578301633716722,1.0592257700382022,1.0642495557255702,1.0640603109784084,1.048955865409396,1.0579208734385463,1.047735547253845,1.0471584312959548,1.048906129434568,1.046241603586652,1.0933964894999058,1.0431324366582644,1.042942467085812,1.0423479405565,1.0389070543674155,1.039830742899431,1.0374359146717491,1.040503445021603,1.039283394266706,1.0382741041686556,1.0623424832427173,1.0316915386313692,1.0413588523317914,1.0305521578416912,1.0356110468370106,1.0298987479384887,1.0325886637245842,1.0273909161397077,1.0327207008633046,1.0289149139452418,1.026784647221959,1.0277394815049041,1.0261858146671856,1.0250329886554579,1.024055179379402,1.0220957127732968,1.0290670742135528,1.0301718203299637,1.02526245696829,1.0405350379440763,1.0173108897624759,1.019828536915123,1.0328872564735763,1.0227408462434733,1.034631538008331,1.0279084490526706,1.0158778628624907,1.0307769305115446,1.0199992257520694,1.0344236236099804,1.0280784067757633,1.0196486777121867,1.0195186559213412,1.0259900773883959,1.01496787711021,1.0165507954741837,1.012456308537667,1.0144733390130034,1.0156107615987096,1.0287046448900066,1.0179825980182087,1.0180490916475244,1.0436967570300495,1.0369119285990338,1.0129904766148383,1.0147964068509023,1.0119087234002735,1.0097387498671855,1.0107868893430867,1.0092689772264674,1.0078917252361228,1.0093752408246381,1.022190937345181,1.0106635260472603,1.0091840608404317,1.0069097551183963,1.0100456506287285,1.009902825049304,1.0207256507982903,1.0056808508864237,1.012881439486775,1.006253082271016,1.004031009083494,1.0090598289026034,1.0051900572186216,1.0028207302093506,1.0053541274792557,1.0341852454964173,1.0118779471708,1.0108146372191402,1.0065182714013878,1.006486471229737],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"size":6,"symbol":"square"},"mode":"lines+markers","name":"Validation Loss","x":{"dtype":"i2","bdata":"AQACAAMABAAFAAYABwAIAAkACgALAAwADQAOAA8AEAARABIAEwAUABUAFgAXABgAGQAaABsAHAAdAB4AHwAgACEAIgAjACQAJ ...

# %% [markdown]
# ### Model Evaluation
#
# As can be seen, training converged well. Let's load the best model checkpoint and compare the performance on the test set.
# The overall and per-parameter metrics show that the performance can be improved.

# %%
experiment = runner.load_checkpoint("cnn1d_n1/b278dc3a0d3a416f81d5c44978fad2ea/best")
# experiment.load_checkpoint("best")

y_pred, y_true, loss = experiment.trainer.evaluate(dm.test_dataloader)

col_names = get_param_names(n_actions, ic=True)

metrics = compute_metrics(y_true, y_pred)
plot_metrics(metrics, target_names=col_names)
plot_parameter_comparison(y_true, y_pred, col_names)
# Out:
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/b278dc3a0d3a416f81d5c44978fad2ea/best.pt
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="9ffda1c2-fe51-49d5-ab1a-e5c62f00af8d" class="plotly-graph-div" style="height:1000px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9ffda1c2-fe51-49d5-ab1a-e5c62f00af8d")) {                    Plotly.newPlot(                        "9ffda1c2-fe51-49d5-ab1a-e5c62f00af8d",                        [{"name":"Overall Metrics","text":["0.9518","0.9756","0.0976","0.6153","0.5345","0.2631","0.4250","0.6859","0.8307","0.9347"],"textposition":"outside","x":["MSE","RMSE","NRMSE (range)","NRMSE (std)","MAE","MedAE","MRE","R\u00b2","Pearson r","Spearman r"],"y":[0.9518119692802429,0.9756085123041122,0.09764887309287527,0.6152889212147388,0.5344512462615967,0.26306137442588806,0.42504146695137024,0.6859318614006042,0.8306933641433716,0.9347019683844796],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"
2QB+70z7NYPQ\u002fed3bP\u002fSU7D8hjARA1iQDPyVozj\u002fkUQpAlbcaP2688T\u002fm8fQ+Fw01P9CxJkCMKmc\u002fMdQeQB7Q8j3ZCBpAbFQHQOA3+D\u002fHHQpAV38gQJ\u002fyBEC\u002fvRNAQuU8P4DGwD6U2NU\u002f5Y7jP5Dr7j96gAJAykZHP5iFK0D+l5c\u002fKvO6PzISAEBOOZA\u002fomwaQKqlJz9lh+8\u002fNsIRPtW2pD4jQQtAkC8+Pxf0az8wqrQ940clQAVC6j\u002fYeuU\u002ffQWPP9Obaj\u002fao70+IVwfQKg0AT\u002f7KM8\u002fDLBmPiHXFkAA8dg\u002fgoVrP8cPQT9064Q\u002foQYvQBY34D9TeixAqZGmP42gEkAcTYM\u002fDX8JP30TxT\u002fQwhhA261QP5j6dT9Tc94\u002fF1xwPv ...

# %% [markdown]
# ## Hyperparameter Optimization
#
# Let's do some hyperparameter studies on the learning rate, and number of filters, and hidden dimensions.
#
# For this, I subclass the `ExperimentRunner` and override the `suggest_parameters` method.
#
# ### Learning Rate

# %%
class Runner(ExperimentRunner):
    def suggest_parameters(self, trial):
        lr = trial.suggest_float("lr", 1e-4, 1e-1, log=True)
        self.trainer_config.learning_rate = lr


runner = Runner(
    runner_config=runner_config,
    data_config=data_config,
    model_config=model_config,
    trainer_config=trainer_config,
)

# %%
study = runner.run_study("lr_study", n_trials=10, n_jobs=1)
# Out:
# [I 2026-01-07 12:27:36,691] Using an existing study with name 'lr_study' instead of creating a new one.
# INFO:preference_dynamics.experiments.runner:Run: Trial 5: lr=0.03767215131687004
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 200 epochs with run_id=5d5e1771edb7424aa481c9a449140cbe
# Training:  24%|██▍       | 48/200 [01:19<04:12,  1.66s/it, epoch=48, train_loss=1.78, val_loss=1.78, epoch_time=1.86]INFO:preference_dynamics.training.trainer:Early stopping at epoch 48 (patience: 20)
# Training:  24%|██▍       | 48/200 [01:19<04:10,  1.65s/it, epoch=48, train_loss=1.78, val_loss=1.78, epoch_time=1.86]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/5d5e1771edb7424aa481c9a449140cbe/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 1.7159060550772625
# [I 2026-01-07 12:29:05,738] Trial 5 finished with value: 1.7159060550772625 and parameters: {'lr': 0.03767215131687004}. Best is trial 2 with value: 0.9447939110838849.
# INFO:preference_dynamics.experiments.runner:Run: Trial 6: lr=0.08198285839175667
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 200 epochs with run_id=7c9e16f67e624af0b9b62b04ea03d860
# Training:  25%|██▌       | 50/200 [01:37<04:50,  1.94s/it, epoch=50, train_loss=1.97, val_loss=1.99, epoch_time=1.64]INFO:preference_dynamics.training.trainer:Early stopping at epoch 50 (patience: 20)
# Training:  25%|██▌       | 50/200 [01:37<04:51,  1.94s/it, epoch=50, train_loss=1.97, val_loss=1.99, epoch_time=1.64]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/7c9e16f67e624af0b9b62b04ea03d860/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 1.9362680601037068
# [I 2026-01-07 12:30:52,234] Trial 6 finished with value: 1.9362680601037068 and parameters: {'lr': 0.08198285839175667}. Best is trial 2 with value: 0.9447939110838849.
# INFO:preference_dynamics.experiments.runner:Run: Trial 7: lr=0.00017038045538390336
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 200 epochs with run_id=b82e509bb04f4038975df19561eecfe4
# Training: 100%|██████████| 200/200 [06:28<00:00,  1.94s/it, epoch=199, train_loss=1.27, val_loss=1.16, epoch_time=1.9]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/b82e509bb04f4038975df19561eecfe4/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 1.11228070570075
# [I 2026-01-07 12:37:30,636] Trial 7 finished with value: 1.11228070570075 and parameters: {'lr': 0.00017038045538390336}. Best is trial 2 with value: 0.9447939110838849.
# INFO:preference_dynamics.experiments.runner:Run: Trial 8: lr=0.003098806802987717
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 200 epochs with run_id=a7f0d021bfd349ceb5f7ba713cb78251
# Training:  82%|████████▏ | 164/200 [05:16<00:59,  1.66s/it, epoch=164, train_loss=0.996, val_loss=0.983, epoch_time=1.63]INFO:preference_dynamics.training.trainer:Early stopping at epoch 164 (patience: 20)
# Training:  82%|████████▏ | 164/200 [05:16<01:09,  1.93s/it, epoch=164, train_loss=0.996, val_loss=0.983, epoch_time=1.63]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/a7f0d021bfd349ceb5f7ba713cb78251/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 0.9470055362452632
# [I 2026-01-07 12:42:57,051] Trial 8 finished with value: 0.9470055362452632 and parameters: {'lr': 0.003098806802987717}. Best is trial 2 with value: 0.9447939110838849.
# INFO:preference_dynamics.experiments.runner:Run: Trial 9: lr=0.00762077791577325
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 200 epochs with run_id=6b0aaa82d9d4482da0bc9c34d1045589
# Training:  82%|████████▏ | 163/200 [05:24<01:08,  1.86s/it, epoch=163, train_loss=1, val_loss=0.992, epoch_time=1.51]    INFO:preference_dynamics.training.trainer:Early stopping at epoch 163 (patience: 20)
# Training:  82%|████████▏ | 163/200 [05:24<01:13,  1.99s/it, epoch=163, train_loss=1, val_loss=0.992, epoch_time=1.51]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/6b0aaa82d9d4482da0bc9c34d1045589/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 0.9487612104934194
# [I 2026-01-07 12:48:31,156] Trial 9 finished with value: 0.9487612104934194 and parameters: {'lr': 0.00762077791577325}. Best is trial 2 with value: 0.9447939110838849.

# %%
study = runner.load_study("lr_study")  # if not loaded already
plot_parallel_coordinate(study)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="581c4543-64f5-47b7-a825-b82067218163" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("581c4543-64f5-47b7-a825-b82067218163")) {                    Plotly.newPlot(                        "581c4543-64f5-47b7-a825-b82067218163",                        [{"dimensions":[{"label":"Objective Value","range":[0.9447939110838849,1.9362680601037068],"values":[1.6106399686440178,0.9508308586866959,0.9447939110838849,1.0071322425552036,0.9575489033823428,1.7159060550772625,1.9362680601037068,1.11228070570075,0.9470055362452632,0.9487612104934194]},{"label":"lr","range":[-3.7685802253307386,-1.0862769437637727],"ticktext":["0.00017","0.001","0.01","0.082"],"tickvals":[-3.7685802253307386,-3,-2,-1.0862769437637727],"values":[-1.554493379375293,-2.8336463235222764,-2.6002070922594887,-1.6046673737621098,-2.86810885955109,-1.423979578141101,-1.0862769437637727,-3.7685802253307386,-2.5088054992727646,-2.118000694371183]}],"labelangle":30,"labelside":"bottom","line":{"color":[1.6106399686440178,0.9508308586866959,0.9447939110838849,1.0071322425552036,0.9575489033823428,1.7159060550772625,1.9362680601037068,1.11228070570075,0.9470055362452632,0.9487612104934194],"colorbar":{"title":{"text":"Objective Value"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"reversescale":true,"showscale":true},"type":"parcoords"}],                        {"title":{"text":"Parallel Coordinate Plot"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]} ...

# %% [markdown]
# As can be seen, anything between 1e-3 and 1e-2 is the best learning rate. I choose the best-performing trial with lr=0.082 for fastest convergence.
#
# ### CNN and MLP Layers
#
# Next, I vary the number of convolutional and hidden layers.

# %%
trainer_config = TrainerConfig(
    loss_function="mse",
    learning_rate=0.082,
    num_epochs=200,
    early_stopping_patience=20,
)


class Runner(ExperimentRunner):
    def suggest_parameters(self, trial):
        n_kernels = trial.suggest_int("n_kernels", 1, 4)
        self.model_config.kernel_sizes = [3] * n_kernels
        self.model_config.filters = [64] * n_kernels
        n_hidden_layers = trial.suggest_int("n_hidden_layers", 1, 3)
        self.model_config.features = [32] * n_hidden_layers + [dm.n_targets]


runner = Runner(
    runner_config=runner_config,
    data_config=data_config,
    model_config=model_config,
    trainer_config=trainer_config,
)

# %%
study = runner.run_study("num_kernels_hidden_study", n_trials=12, n_jobs=1)
# Out:
# [I 2026-01-06 16:14:35,731] Using an existing study with name 'num_kernels_hidden_study' instead of creating a new one.
# INFO:preference_dynamics.experiments.runner:Run: Trial 14: n_kernels=2, n_hidden_layers=1
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 100 epochs with run_id=ef5aacd2bf744924a269125396dc3acb
# Training: 100%|██████████| 100/100 [03:59<00:00,  2.40s/it, epoch=99, train_loss=0.94, val_loss=0.939, epoch_time=2.67]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/ef5aacd2bf744924a269125396dc3acb/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 0.9037303820900295
# [I 2026-01-06 16:18:49,499] Trial 14 finished with value: 0.9037303820900295 and parameters: {'n_kernels': 2, 'n_hidden_layers': 1}. Best is trial 10 with value: 0.8958729201036951.

# %% [markdown]
# The contour plot shows that only 1 convolutional layer performs worse. Apart from that, all combinations of layers perform similarly, which can be verified in the parallel coordinate plot.
#
# The plot shows that performance does not increase significantly beyond a parsimonious model with 2 convolutional and 1 hidden layer.

# %%
study = runner.load_study("num_kernels_hidden_study")
plot_contour(study)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="0ae0e273-13c6-4cdd-b67f-7435504d019b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0ae0e273-13c6-4cdd-b67f-7435504d019b")) {                    Plotly.newPlot(                        "0ae0e273-13c6-4cdd-b67f-7435504d019b",                        [{"colorbar":{"title":{"text":"Objective Value"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"connectgaps":true,"contours":{"coloring":"heatmap"},"hoverinfo":"none","line":{"smoothing":1.3},"reversescale":true,"x":[0.9,1,2,3,3.1],"y":[0.85,1,2,3,4,4.15],"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002f9aY3vQqe7z8AAAAAAAD4f05veuN4Ue4\u002fAAAAAAAA+H8AAAAAAAD4f+pNb\u002fpb6+w\u002f6k1vOoTW7D9ZyELGQszsPwAAAAAAAPh\u002fAAAAAAAA+H+RhSwc6qzsP\u002fWmN+1esew\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fspCFjCHK7D\u002ff9Kav\u002farsPwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002f","shape":"6, 5"},"type":"contour"},{"marker":{"color":"black","line":{"color":"Gray","width":2.0}},"mode":"markers","name":"Feasible Trial","showlegend":false,"x":[2,3,3,1,2,1,1,1,1,1,2,2,1],"y":[3,1,2,3,2,1,1,1,3,4,4,4,2],"type":"scatter"},{"marker":{"color":"#cccccc","line":{"color":"Gray","width":2.0}},"mode":"markers","name":"Infeasible Trial","showlegend":false,"x":[],"y":[],"type":"scatter"}],                        {"title":{"text":"Contour Plot"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]] ...

# %% [markdown]
# ### Number of Filters and Neurons
#
# The next hyperparameter study investigates the optimal number of neurons per layer / filters per CNN layer. I use the optimal number of layers from the previous study.
#
# The results:
# - `filter_0=64-96` is generally best
# - `filter_1=128` significantly improves performance
# - `neurons=128` or `64` yields ambiguous results

# %%
model_config = CNN1DConfig(
    model_name=model_name,
    in_channels=dm.n_inputs,
    filters=[64, 64],
    kernel_sizes=[3, 3],
    features=[32, dm.n_targets],
    dropout=0.3,
)


class Runner(ExperimentRunner):
    def suggest_parameters(self, trial):
        filters = [trial.suggest_int(f"filter_{i}", 32, 128, step=32) for i in range(2)]
        self.model_config.filters = filters
        neurons = trial.suggest_int("neurons", 32, 128, step=32)
        self.model_config.features = [neurons] + [dm.n_targets]


runner = Runner(
    runner_config=runner_config,
    data_config=data_config,
    model_config=model_config,
    trainer_config=trainer_config,
)

# %%
study = runner.run_study("num_filters_neurons_study", n_trials=12, n_jobs=1)
# Out:
# [I 2026-01-06 17:55:28,355] Using an existing study with name 'num_filters_neurons_study' instead of creating a new one.
# INFO:preference_dynamics.experiments.runner:Run: Trial 11: filter_0=96, filter_1=96, neurons=96
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.data.manager:Loading raw data from data/n1/raw
# INFO:preference_dynamics.data.manager:Saving 3 splits to data/n1/processed
# INFO:preference_dynamics.training.trainer:Starting training for 100 epochs with run_id=2234dcff39e74d0d85ad2faa7046c6e6
# Training: 100%|██████████| 100/100 [03:48<00:00,  2.28s/it, epoch=99, train_loss=0.927, val_loss=0.931, epoch_time=3.36]
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/2234dcff39e74d0d85ad2faa7046c6e6/best.pt
# INFO:preference_dynamics.training.trainer:Test loss: 0.8987486848364705
# [I 2026-01-06 17:59:28,057] Trial 11 finished with value: 0.8987486848364705 and parameters: {'filter_0': 96, 'filter_1': 96, 'neurons': 96}. Best is trial 5 with value: 0.8945477455854416.

# %%
study = runner.load_study("num_filters_neurons_study")
display(plot_contour(study))
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="03ed9d3a-cbd6-42c4-8955-0e372e10baa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("03ed9d3a-cbd6-42c4-8955-0e372e10baa7")) {                    Plotly.newPlot(                        "03ed9d3a-cbd6-42c4-8955-0e372e10baa7",                        [{"type":"scatter","xaxis":"x","yaxis":"y"},{"colorbar":{"title":{"text":"Objective Value"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"connectgaps":true,"contours":{"coloring":"heatmap"},"hoverinfo":"none","line":{"smoothing":1.3},"reversescale":true,"showscale":true,"x":[27.2,32,64,96,128,132.8],"y":[27.2,32,64,96,128,132.8],"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fvelN398P7T9Ob3rDz5DtPwAAAAAAAPh\u002fAAAAAAAA+H+c3vTGmPHsPzi96R2jzuw\u002fAAAAAAAA+H8tZCG7HtfsPwAAAAAAAPh\u002fAAAAAAAA+H9Ob3rTmtPsPwAAAAAAAPh\u002fyEIWmozC7D8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f0MWsqCEpOw\u002fAAAAmCKg7D8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002f","shape":"6, 6"},"type":"contour","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"black","line":{"color":"Gray","width":2.0}},"mode":"markers","name":"Feasible Trial","showlegend":false,"x":[128,32,64,64,32,96,128,96,64,96,96,96],"y":[32,64,128,64,96,128,64,32,128,96,128,96],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"colorbar":{"title":{"text":"Objective Value"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"connectgaps":true,"contours":{"coloring":"heatmap"},"hoverinfo":"none","line":{"smoothing":1.3},"reversescale":true,"showscale":false,"x":[27.2,32,64,96,128,132.8],"y":[27.2,32,64,96,128,132.8],"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002f6k1vKofH7D8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H9Ob3rTmtPsPzi96R2jzuw\u002fAAAAmCKg7D8tZCG7HtfsPwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fyEIWmozC7D8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H+c3vTGmPHsP0MWsqCEpOw\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002f","shape":"6, 6"},"type":"contour","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"black","line":{"color":"Gray","width":2.0}},"mode":"markers","name":"Feasible Trial","showlegend":false,"x":[128,32,64,64,32,96,128,96,64,96,96,96],"y":[64,128,128,64,64,64,64,96,128,32,32,96],"type":"scatter","xaxis":"x7","yaxis":"y7"},{"colorbar":{"title":{"text":"Objective Value"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"connectgaps":true,"contours":{"coloring":"heatmap"},"hoverinfo":"none","line":{"smoothing":1.3},"reversescale":true,"showscale":false,"x":[27.2,32,64,96,128,132.8],"y":[27.2,32,64,96,128,132.8],"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f5ze9MaY8ew\u002fTm9605rT7D8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fzi96R2jzuw\u002fAAAAAAAA+H9DFrKghKTsPwAAAAAAAPh\u002fAAAAAAAA+H+96U3f3w\u002ftPwAAAAAAAPh\u002fy ...

# %% [markdown]
# The overall metrics over the best run show a significant improvement in model performance.
# The per-parameter comparisons show less spread, however the model still struggles to reproduce $g_0$.
#
# The prediction of $m_0<0$ and $v_0<0$ is particularly challenging, since these values cannot be inferred directly from the time series, which is reflected in the results.

# %%
run_id = [
    t.user_attrs["mlflow_run_id"]
    for t in study.trials
    if t.params == {"filter_0": 64, "filter_1": 128, "neurons": 128}
][0]
checkpoint_path = assemble_checkpoint_path(["best"], model_name=model_name, run_id=run_id)

experiment = runner.load_checkpoint(checkpoint_path)

y_pred, y_true, loss = experiment.trainer.evaluate(dm.test_dataloader)

metrics = compute_metrics(y_true, y_pred)
plot_metrics(metrics, col_names)
plot_parameter_comparison(y_true, y_pred, col_names)
# Out:
# INFO:preference_dynamics.training.trainer:Initialized Trainer with device=cuda, checkpoint_dir=checkpoints
# INFO:preference_dynamics.training.trainer:Loading checkpoint from checkpoints/cnn1d_n1/c1049714fb634f14870a1908fcc33531/best.pt
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="efdeec62-2554-4c5e-84f0-2c789c1e0071" class="plotly-graph-div" style="height:1000px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("efdeec62-2554-4c5e-84f0-2c789c1e0071")) {                    Plotly.newPlot(                        "efdeec62-2554-4c5e-84f0-2c789c1e0071",                        [{"name":"Overall Metrics","text":["0.8951","0.9461","0.0947","0.5967","0.4607","0.1425","0.3438","0.7501","0.8431","0.9563"],"textposition":"outside","x":["MSE","RMSE","NRMSE (range)","NRMSE (std)","MAE","MedAE","MRE","R\u00b2","Pearson r","Spearman r"],"y":[0.8950830101966858,0.9460882676561875,0.09469418523710012,0.596671331008889,0.46067044138908386,0.14254215359687805,0.34384164214134216,0.7500773072242737,0.8430800437927246,0.9563005726927615],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Per-Target RMSE","showlegend":false,"text":["0.4809","0.00e+00","0.1913","0.1850","2.0836","0.8526"],"textposition":"outside","x":[0,1,2,3,4,5],"y":{"dtype":"f4","bdata":"pjT2PgAAAABj30M+PnE9PnhaBUCOQVo\u002f"},"type":"bar","xaxis":"x3","yaxis":"y3"},{"name":"Per-Target NRMSE","showlegend":false,"text":["0.1604","0.00e+00","0.0661","0.0638","0.2086","0.2135"],"textposition":"outside","x":[0,1,2,3,4,5],"
002f5Y7jP5Dr7j96gAJAykZHP5iFK0D+l5c\u002fKvO6PzISAEBOOZA\u002fomwaQKqlJz9lh+8\u002fNsIRPtW2pD4jQQtAkC8+Pxf0az8wqrQ940clQAVC6j\u002fYeuU\u002ffQWPP9Obaj\u002fao70+IVwfQKg0AT\u002f7KM8\u002fDLBmPiHXFkAA8dg\u002fgoVrP8cPQT9064Q\u002foQYvQBY34D9TeixAqZGmP42gEkAcTYM\u002fDX8JP30TxT\u002fQwhhA261QP5j6dT9Tc94\u002fF1xwPv ...

# %% [markdown]
# ## Time Series Comparison
#
# The real test is however, if the model can faithfully recreate the time series.
# Let's look at some examples. s=0 is the time series for the true parameters, and s=1 is the time series for the predicted parameters.
# The model somewhat captures the behavior, but does not faithfully reproduce the steady state.

# %%
# Visual comparison of true and predicted time series

solver_config = SolverConfig(
    time_span=(0.0, 200.0),
    n_time_points=401,
)
n_params = num_params(n_actions)
n_vars = num_vars(n_actions)

for i in range(5):
    samples = []
    try:
        for name, y in {"true": y_true.cpu().numpy()[i], "pred": y_pred.cpu().numpy()[i]}.items():
            config_ode = ODEConfig(
                parameters=ParameterVector(values=y[:n_params]),
                initial_conditions=ICVector(values=y[n_params : n_params + n_vars]),
            )
            config = ODESolverConfig(ode=config_ode.model_dump(), solver=solver_config)

            sample = solve_ODE(config)
            samples.append(sample)
        plot_time_series(samples)
    except ValueError:
        continue
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="e960804c-458d-46f2-943c-2ec6d85cdfd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e960804c-458d-46f2-943c-2ec6d85cdfd9")) {                    Plotly.newPlot(                        "e960804c-458d-46f2-943c-2ec6d85cdfd9",                        [{"hovertemplate":"Variable=Desire u_0, s=0\u003cbr\u003eType=Desire\u003cbr\u003eTime=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desire u_0, s=0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Desire u_0, s=0","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADgPwAAAAAAAPA\..."},"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAAADqSMf\u002fJCWZP85+rR15g\u002fQ\u002fWINhBXUyA0Ayqyg+RuQJQLi9RLTpIw5Av\u002fKGVBgkEECB7DgyhXEQQHjj2d3lRRBAunmXmwHBD0DG+eu+lNwOQJUf5GgPFA5Ajwrng2t\u002fDUAhvDxHLyINQHk7064f9AxAxvF1ZSDoDEAJ\u002f9gH1fAMQIgN\u002f80wAw1AEcJBfG4XDUDH\u002f\u002fEl\u002fSgNQJOeNwffNQ1AJlLMgts9DUCXmI6tuEENQElYs4qiQg1AkIofYMhBDUDzlcecH0ANQHWY39lUPg1ARXjGg8s8DUC4bnv0rTsNQLZ5WrH+Og1AK+Ix7Ks6DUA8uhOQmjoNQJIFOb2uOg1AoRGgXNU6DUDM\u002fBvJ\u002fToNQK0qFCogOw1AB1ZRFzk7DUAEpaEvSDsNQDFi9StPOw1AH6iB\u002fE87DUBgk6Q3TjsNQKeQertLOw1AeS\u002fTWUg7DUANtgAYRTsNQKtkfttCOw1AlQHRpkE7DUDuFEnrQDsNQHLgc9hAOw1ATEm\u002fBkE7DUCMlp8bQTsNQBYqoglBOw1Ar89rEEE7DUBvJJZ1QTsNQMdkTuJBOw1ATQiEC0I7DUAqKlnc